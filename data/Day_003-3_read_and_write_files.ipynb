# %% [markdown]
# ## 讀取圖片
# 常見的套件:
# 1. skimage
# 2. PIL
# 3. OpenCV

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import skimage.io as skio
img1 = skio.imread('/Users/gary/data_marathon/Part01/example.jpg')
plt.imshow(img1)
plt.show()

# %%
from PIL import Image
img2 = Image.open('/Users/gary/data_marathon/Part01/example.jpg') # 這時候還是 PIL object
img2 = np.array(img2)
plt.imshow(img2)
plt.show()

# %%
import cv2
img3 = cv2.imread('/Users/gary/data_marathon/Part01/example.jpg')
plt.imshow(img3)
plt.show()

img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
plt.imshow(img3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-35396f3956cb> in <module>()
# ----> 1 import cv2
#       2 img3 = cv2.imread('/Users/gary/data_marathon/Part01/example.jpg')
#       3 plt.imshow(img3)
#       4 plt.show()
#       5
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# ### 比較三種開圖方式的時間 - 比較讀取 1000 次

# %%
N_times = 1000

# %%
# %%timeit
im = np.array([skio.imread('/Users/gary/data_marathon/Part01/example.jpg') for _ in range(N_times)])
# Out:
# 21.5 s ± 3.89 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
im = np.array([np.array(Image.open('/Users/gary/data_marathon/Part01/example.jpg')) for _ in range(N_times)])
# Out:
# 1 loop, best of 3: 17.1 s per loop

# %%
# %%timeit
im = np.array([cv2.cvtColor(cv2.imread('/Users/gary/data_marathon/Part01/example.jpg'), cv2.COLOR_BGR2RGB) for _ in range(N_times)])
# Out:
# 1 loop, best of 3: 16.5 s per loop

# %% [markdown]
# ## 將影像存成 mat

# %%
import scipy.io as sio
sio.savemat(file_name='data/examples/example.mat', mdict={'img': img1})

# %%
mat_arr = sio.loadmat('data/examples/example.mat')
print(mat_arr.keys())
# Out:
# dict_keys(['__version__', 'img', '__globals__', '__header__'])

# %%
mat_arr = mat_arr['img']
print(mat_arr.shape)
# Out:
# (813, 771, 3)

# %%
plt.imshow(mat_arr)
plt.show()

# %% [markdown]
# # 練習時間
#
# ## 1-1 讀取 txt 檔
# * 請讀取 [text file](https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt)
# * 懶人複製連結: https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt
#
# ## 1-2 將所提供的 txt 轉成 pandas dataframe
#
# ## 2. 從所提供的 txt 中的連結讀取圖片，請讀取上面 data frame 中的前 5 張圖片
